# %% [markdown]
# <a href="https://colab.research.google.com/github/JABU-2022/English_to_Kinyarwanda_Translation_with_RNNs/blob/main/English_to_Kinyarwanda_Translation_with_RNNs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **English_to_Kinyarwanda_Translation_with_RNNs**

# %% [markdown]
# To build a model that translates text from English to Kinyarwanda, we can use the Kinyarwanda-English parallel dataset provided by Digital Umuganda on Hugging Face. This dataset contains 48,000 Kinyarwanda-English parallel sentences, which is suitable for training a machine translation model.

# %% [markdown]
# **STEPS TO BUILD THE TRANSLATION MODEL**

# %% [markdown]
# **1. Data Collection and Preprocessing**

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Embedding, GRU, Dense, Bidirectional
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction



# Function to read data with specific encoding and error handling
def read_data_with_encoding(url, encoding='utf-8'):
    try:
        return pd.read_csv(url, sep='\t', names=['English', 'Kinyarwanda'], encoding=encoding, on_bad_lines='skip')
    except UnicodeDecodeError:
        print(f"UnicodeDecodeError encountered while reading {url} with encoding {encoding}")
        return None

# Load the datasets
urls = [
    'https://huggingface.co/datasets/DigitalUmuganda/kinyarwanda-english-machine-translation-dataset/resolve/main/kinyarwanda-english-corpus.tsv',
    'https://huggingface.co/datasets/DigitalUmuganda/kinyarwanda-english-machine-translation-dataset/resolve/main/kinyarwanda-english-corpus2.tsv',
    'https://huggingface.co/datasets/DigitalUmuganda/kinyarwanda-english-machine-translation-dataset/resolve/main/kinyarwanda-english-corpus3.tsv'
]

dfs = [read_data_with_encoding(url, encoding='ISO-8859-1') for url in urls]
df = pd.concat(dfs, ignore_index=True)

# Drop any rows with NaN values
df.dropna(inplace=True)

# Preprocess the text
def preprocess(text):
    text = text.lower()
    text = ''.join(char for char in text if char.isalnum() or char.isspace())
    return text

df['English'] = df['English'].apply(preprocess)
df['Kinyarwanda'] = df['Kinyarwanda'].apply(preprocess)

# Add special tokens
def add_special_tokens(texts):
    return ['<start> ' + text + ' <end>' for text in texts]

df['English'] = add_special_tokens(df['English'])
df['Kinyarwanda'] = add_special_tokens(df['Kinyarwanda'])

# Split the data into training and validation sets
train_data, val_data = train_test_split(df, test_size=0.2, random_state=42)

# %% [markdown]
# **2. TOKENIZATION AND PADDING**
#
# >Converts text into sequences of integers, and ensures these sequences are of equal length by performing tokenization and padding.

# %%
# Tokenize the text
def tokenize_text(texts):
    tokenizer = Tokenizer(filters='')
    tokenizer.fit_on_texts(texts)
    sequences = tokenizer.texts_to_sequences(texts)
    return sequences, tokenizer

# Tokenize English and Kinyarwanda texts
english_texts = train_data['English'].tolist()
kinyarwanda_texts = train_data['Kinyarwanda'].tolist()

english_sequences, english_tokenizer = tokenize_text(english_texts)
kinyarwanda_sequences, kinyarwanda_tokenizer = tokenize_text(kinyarwanda_texts)

# Pad sequences
max_seq_length = max(max(len(seq) for seq in english_sequences), max(len(seq) for seq in kinyarwanda_sequences))
english_padded = pad_sequences(english_sequences, maxlen=max_seq_length, padding='post')
kinyarwanda_padded = pad_sequences(kinyarwanda_sequences, maxlen=max_seq_length, padding='post')

# Convert to numpy arrays
english_padded = np.array(english_padded)
kinyarwanda_padded = np.array(kinyarwanda_padded)

# Ensure inp_lang and targ_lang are defined correctly
inp_lang = english_tokenizer
targ_lang = kinyarwanda_tokenizer
max_length_inp = max_seq_length
max_length_targ = max_seq_length

# %% [markdown]
# **3. Model Development**

# %% [markdown]
# For the translation model, we'll use an RNN-based architecture with an encoder-decoder structure. We can use GRU or LSTM units for the RNNs, and integrate pre-trained word embeddings like Word2Vec or GloVe.

# %% [markdown]
# **Example code for building the model:**

# %%
# Define the Encoder
class Encoder(Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = Embedding(vocab_size, embedding_dim)
        self.gru = Bidirectional(GRU(self.enc_units,
                                     return_sequences=True,
                                     return_state=True,
                                     recurrent_initializer='glorot_uniform'))

    def call(self, x, hidden):
        x = self.embedding(x)
        output, forward_h, backward_h = self.gru(x, initial_state=hidden)
        state = tf.concat([forward_h, backward_h], axis=-1)
        return output, state

    def initialize_hidden_state(self, batch_size):
        return [tf.zeros((batch_size, self.enc_units)) for _ in range(2)]

# Define the Decoder
class Decoder(Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = Embedding(vocab_size, embedding_dim)
        self.gru = GRU(self.dec_units,
                       return_sequences=True,
                       return_state=True,
                       recurrent_initializer='glorot_uniform')
        self.fc = Dense(vocab_size)

    def call(self, x, hidden, enc_output):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state=hidden)
        output = self.fc(output)
        return output, state

# Initialize model parameters
embedding_dim = 256
units = 512
vocab_inp_size = len(inp_lang.word_index) + 1
vocab_tar_size = len(targ_lang.word_index) + 1
BATCH_SIZE = 64

# Instantiate Encoder and Decoder
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
decoder = Decoder(vocab_tar_size, embedding_dim, units * 2, BATCH_SIZE)

# %% [markdown]
# **4. Training the Model**

# %% [markdown]
# Train the model with the prepared dataset, tuning the hyperparameters like batch size, learning rate, and the number of epochs.

# %% [markdown]
# **Example code for training:**

# %%
# Training process
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

# Training step function
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0
    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)
        dec_hidden = enc_hidden
        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)
        for t in range(1, targ.shape[1]):
            predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_output)
            loss += loss_function(targ[:, t], predictions)
            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = (loss / int(targ.shape[1]))
    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %% [markdown]
# **5. Evaluation**

# %% [markdown]
# Evaluate the model using metrics such as BLEU score and human evaluations to ensure the translations are accurate and fluent.

# %% [markdown]
# **Example code for evaluation:**

# %%
# Evaluation function
def evaluate(sentence):
    sentence = '<start> ' + sentence + ' <end>'
    inputs = [inp_lang.word_index.get(i, 0) for i in sentence.split(' ')]
    inputs = pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)

    result = ''
    hidden = encoder.initialize_hidden_state(1)
    enc_out, enc_hidden = encoder(inputs, hidden)
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)
        predicted_id = tf.argmax(predictions[0, -1]).numpy().item()  # Convert to integer
        result += targ_lang.index_word[predicted_id] + ' '
        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence

# %% [markdown]
# **Calculate BLEU score for a batch of sentences**

# %%
# Calculate BLEU score for a batch of sentences
def calculate_bleu(reference, candidate):
    smoothing_function = SmoothingFunction().method4
    return sentence_bleu([reference.split()], candidate.split(), smoothing_function=smoothing_function)

def evaluate_batch(test_data):
    total_bleu_score = 0.0
    for idx, row in test_data.iterrows():
        reference = row['Kinyarwanda']
        candidate, _ = evaluate(row['English'])
        bleu_score = calculate_bleu(reference, candidate)
        total_bleu_score += bleu_score
        print(f"Reference: {reference}")
        print(f"Candidate: {candidate}")
        print(f"BLEU score: {bleu_score}")
    average_bleu_score = total_bleu_score / len(test_data)
    print(f"Average BLEU score: {average_bleu_score}")
    return average_bleu_score

# Example evaluation call
example_sentence = "hello how are you"
translation, sentence = evaluate(example_sentence)
print(f'Translation: {translation}')

# Evaluate BLEU score on validation data
average_bleu_score = evaluate_batch(val_data)
print(f'Average BLEU score on validation data: {average_bleu_score}')
# Out:
# Translation: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# Reference: <start> she got married with nick four months after she was proposed <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> the old man stands and looks at the big bucket <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> im a little hesitant to go there alone <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> the man sitting at the back of the table was sitting in the front of the room with his clothes on the wall <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> that was your third drink <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> the media cannot ignore us forever sooner or later they will make a story on us <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> a woman in a dark coat shields her eyes from the sun <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a woman in a dark sweater rides her bicycle to the car <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> and he was punished <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> what is all this mugabo <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> the governor of the state of borono is present <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> it doesnt look like it will happen today <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a man wearing glasses and a white shirt plays an electric guitar <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> this is your problem <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> internationally when is swahili used <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a group of humans and dogs sitting on blachers <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> i have questions i need to ask <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0.0071638813215387015
# Reference: <start> two groups of people are talking <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> your head is verry big why <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> karasira can do this work on his own <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> im sure rukara would be very interested in what you have to say <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> i feel like doing different things today <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a bearded man working on a broken escalator <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> others for drinking alcohol <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> if ever you have to  love someone else <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> for the kingdom of god and comforted him <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> i will ask  to see if anyone has seen or heard of it <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a journey to our future <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a man in a shirt puts a bag on top of his shirt <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> do  you have hope like  <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> they refer to christ to whom all the sacrifices of the old testament pointed <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> it is true that monicque did her best but she did not pay attention to it <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a woman walks out of an asian building <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> mary doesnt understand why the shooter chose the cat as her avatar on the line <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> a baby girl wearing a blue leopard walks in the dark while a mans hand is stretched out to support her <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> due to the economic downturn vws working week has been reduced by hours <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> a sushi restaurant with a man cooking while in the back is a man and a boy sitting at a table <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0.0071638813215387015
# Reference: <start> eventually they decided to take the plane <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> we will use energy sources like sun and wind <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> the white truck is on a busy road <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> tom wants children but mary doesnt <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> if you continue to drink this way you will develop diabetes <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> what a bird what a spider web <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> my father seemed to disappoint me because he never supported me <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> jesus then went to jerusalem <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> the aarons are the one who serves jehovah and the levites help them <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> the gentleman would not do such a thing <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> when you get out of jail he will be married <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start>   a group of seven adults share a meal <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> i dont think its hard to find a good grub here <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a dark dog walks through the flowers <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> if you have a problem ill help you  <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> whats in this closet <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> a group of people wearing protective gear <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> a yellow man in a black dress and managing to stand with a fan in front of the burning trees and the people around him <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> the two girls lay on the grass together <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> selena gomez grew up in grand prairie texas <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0.0071638813215387015
# Reference: <start> she asked him why he was crying but he didnt answer <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> highlight the main points in the text <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> i could only hear the sound of your voice <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> differs from ordinary letters <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start>  you are the shadow of the exit today <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> two dogs <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> i didnt have time to heal before i went down with another horrible cold <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> the man hears over the world over the big rocks <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> i dont know why but he seems to have it <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start>  the temperature was responsible for the meat going wrong <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> you will immediately get used to the new life <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> this is based on the truth <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> i bowed down to take my pen that had fallen to the ground <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> he seems to have the courage but in reality he is a man of great will <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a woman goes up the aisle with her possessions locked on one side <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0.0071638813215387015
# Reference: <start> murinzi told me how to do it <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> what i ate yesterday did not agree <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> he rolled up the newspaper and put it on his desk <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0.0071638813215387015
# Reference: <start> maybe we should all fall asleep <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> it will take a week or so to read in this book <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> kalisa  admitted that i had told the truth <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> dont have another big one <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> if it is protected properly it will not heat up regardless of the temperature you use <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0.0071638813215387015
# Reference: <start> they were stupid and didnt follow your advice <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> coughing is a common cause of chest infections <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> god is omnipotent <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> he said that if he knew his address he would write to him <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> king nebuchadnezzar spent many years in the mountains <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> the train will be closed from tomorrow <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> broke his heart <end>
# Candidate: opportunities seed lingered busy truthfully realizes brake bully bikaba been mukahigiro powerless ko malaria endings snake magazines preparing lingered grinding deases zuckerbergs matt comforted act device barking disciples idiots patties murorunkwere speaker firstb surrounds kindly pizza stayed begin gentle guitar stress
# BLEU score: 0
# Reference: <start> gave them to prepare this country and prepare it for todays kingdom <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> do you want this message to work <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> where they can get pregnant <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> our team will hold its monthly meeting next wednesday <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> how much do you plan to invest in the state <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0.0071638813215387015
# Reference: <start> a boy dressed as spiderman sounds the family bell <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> tell me how it feels to fall in love <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> as a result the greek jews began to murmur against the hebrews <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> im going to do some extra work during the holidays <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> it has become something that is very popular  <end>
# Candidate: opportunities seed lingered busy truthfully realizes brake bully bikaba been mukahigiro powerless ko malaria endings snake magazines preparing lingered grinding deases zuckerbergs matt comforted act device barking disciples idiots patties murorunkwere speaker firstb surrounds kindly pizza stayed begin gentle guitar stress
# BLEU score: 0
# Reference: <start> the apostles had been called to do the work <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> that when they call it copper <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> using this prophecy paul says and isaiah was very bold <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> and i show this to the queen of england <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a child wearing a cowboy hat runs to another child <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> that poem is like a chain <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> god created eart and heaven <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> i want a picture of that dog <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start>  i dont you have needle with a head  <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start>  i see a page cut out of this book <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> the documents say it existed <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> two people in the kitchen <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> and now lord god look at their threats <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> please put a yen stamp on the envelope <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> they say he quit his job <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> they say it is not necessary to interfere in the war <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> and in simple language <end>
# ...
# BLEU score: 0
# Reference: <start> at that time he was paid by the priest for his good deeds <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> i can get any of those anytime i want <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> perhaps rwandans would have seen  <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> i thought you understood <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a man in a black shirt plays the guitar and sings at a concert <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> that is not love <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> speaking and being silent are some of the hallmarks of a wise man <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> crowds stand on the sidewalk while a man in a blue helmet is talking to a taxi driver <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> desire causes greed in people <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start>  the fire goes out for a moment then goes out <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> its history tells us that king heregar had a lot of gold <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> two men in black shirts chatting near a video camera <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> i will do my best to pray for you to do what he has to do <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a young boy in green and beige arrives to catch a ball <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> you dont have to be a native speaker to communicate <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira pose cycle lipstick amazingly down stare dad mushongore up mariya your duke lazyness arose knight back undoubted peaceul base chief 14yearold heating displayed accounts value sample indians gliders juncture utensils scorned macedonian ukrain school
# BLEU score: 0
# Reference: <start> paul was ready <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> and another good thing is that rwandans live happily ever after <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> i could have prevented this <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> this is stated in the following four articles of the law <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> another said to her what you will award me is not expensive <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> kalisa deserved more than this <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> i want you to tell me why you lied <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> they said they would agree to put him in  the committee <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> i have a hundred thousands <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> a man with a hat <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> three men posing <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> i used to look at him but i was no more <end>
# Candidate: opportunities seed bumper piece need wendys counting encloses descended godhead safely bunyambo decisions kalisas graduate slicing pacy wonderful scheduling ta misery everlasting astonishing paint regretted sack steped ndahiro up gazette how instant paganism boasted coloring kid aiming occupants ivani fiancée physique
# BLEU score: 0
# Reference: <start> he is the one who mocks this of the worshipers <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# Reference: <start> it was a time of joy and love <end>
# Candidate: opportunities seed bumper wendys rejoice nkusi kalira africa claudius unpleasant searching hughes vinci vinci heavyweight works philippi gunfire sustainable zakayo foods foods misleading rudahigwa finland imported regulatory scorned selfish summit troops doberman affirmed interested philadelphia described bidders guard cafeine lady forgetting
# BLEU score: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-8f9c8a0ae3d7> in <cell line: 26>()
#      24
#      25 # Evaluate BLEU score on validation data
# ---> 26 average_bleu_score = evaluate_batch(val_data)
#      27 print(f'Average BLEU score on validation data: {average_bleu_score}')
#
# <ipython-input-42-8f9c8a0ae3d7> in evaluate_batch(test_data)
#       8     for idx, row in test_data.iterrows():
#       9         reference = row['Kinyarwanda']
# ---> 10         candidate, _ = evaluate(row['English'])
#      11         bleu_score = calculate_bleu(reference, candidate)
#      12         total_bleu_score += bleu_score
#
# <ipython-input-41-dac80387c248> in evaluate(sentence)
#      14     for t in range(max_length_targ):
#      15         predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)
# ---> 16         predicted_id = tf.argmax(predictions[0, -1]).numpy().item()  # Convert to integer
#      17         result += targ_lang.index_word[predicted_id] + ' '
#      18         if targ_lang.index_word[predicted_id] == '<end>':
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#    1154       var_empty = constant([], dtype=dtypes.int32)
#    1155       packed_begin = packed_end = packed_strides = var_empty
# -> 1156     return strided_slice(
#    1157         tensor,
#    1158         packed_begin,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/array_ops.py in strided_slice(input_, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, var, name)
#    1327     strides = ones_like(begin)
#    1328
# -> 1329   op = gen_array_ops.strided_slice(
#    1330       input=input_,
#    1331       begin=begin,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_array_ops.py in strided_slice(input, begin, end, strides, begin_mask, end_mask, ellipsis_mask, new_axis_mask, shrink_axis_mask, name)
#   10929   if tld.is_eager:
#   10930     try:
# > 10931       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#   10932         _ctx, "StridedSlice", name, input, begin, end, strides, "begin_mask",
#   10933         begin_mask, "end_mask", end_mask, "ellipsis_mask", ellipsis_mask,
#
# KeyboardInterrupt:
